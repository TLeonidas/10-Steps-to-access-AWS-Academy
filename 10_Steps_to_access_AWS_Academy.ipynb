# %% [markdown]
# <a href="https://colab.research.google.com/github/TLeonidas/10-Steps-to-access-AWS-Academy/blob/privacy/10_Steps_to_access_AWS_Academy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 10 Steps to Access AWS Academy & Perform Labs in JupyterLab with SageMaker
#
# ---

# %% [markdown]
# ### This notebook will guide students through the process of accessing your AWS Academy account and launching a lab in JupyterLab using Amazon SageMaker to have an interactive hands-on exercise.

# %% [markdown]
# ## Prerequisites:

# %% [markdown]
# ###1. AWS Academy Account
# ###2. Google Chrome or Firefox
# ###3. Basic Computer Skills

# %% [markdown]
# ## Glossary

# %% [markdown]
# ### 1. Logging in
# ### 2. Selecting the course
# ### 3. Finding the desired LAB
# ### 4. Loading the tool
# ### 5. Starting Lab
# ### 6. Opening Console
# ### 7. Opening Amazon SageMaker
# ### 8. Opening the Notebook instance on JupyterLab
# ### 9. Opening the IPYNB file
# ### 10. Ending Lab
#
# ---

# %% [markdown]
# ## 1. Log in using your student email on AWS Academy Canvas for students:
# ## https://awsacademy.instructure.com/login/canvas

# %% [markdown]
# ![1.PNG](data:image/png;base64,...)

# %% [markdown]
# ## 2. Select the AWS Academy course on the Dashboard:

# %% [markdown]
# ![2.PNG](data:image/png;base64,...)

# %% [markdown]
# ## 3. In Modules, click on the desired Lab:

# %% [markdown]
# ![3.PNG](data:image/png;base64,...)

# %% [markdown]
# ## 4. Load the tool in a new browser window:

# %% [markdown]
# ![4.PNG](data:image/png;base64,...)

# %% [markdown]
# ## 5. Click on "Start Lab" on the top right corner:
# ### It may take about 10 minutes to provision AWS services

# %% [markdown]
# ![5.PNG](data:image/png;base64,...)

# %% [markdown]
# ## 6. Once the Lab is ready, click "Open Console":

# %% [markdown]
# ![11.PNG](data:image/png;base64,...)

# %% [markdown]
# ## 7. Look for Amazon SageMaker on the Console search bar and open it:

# %% [markdown]
# ![7.PNG](data:image/png;base64,...)

# %% [markdown]
# ## 8. In the menu on the left side of the page:
# ## Select "Notebook", then "Notebook instances" before finally opening "JupyterLab":
# ### It may take a few seconds to load the interface

# %% [markdown]
# ![8.PNG](data:image/png;base64,...)

# %% [markdown]
# ## 9. Double click the derised LAB to open it in the platform:

# %% [markdown]
# ![9.PNG](data:image/png;base64,...)

# %% [markdown]
# ## 10. Make sure to "End Lab" after completing the assignments:

# %% [markdown]
# ![6.PNG](data:image/png;base64,...)

# %% [markdown]
# ## Well done! Great achievements lie ahead.
